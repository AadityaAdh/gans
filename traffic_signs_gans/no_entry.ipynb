# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_image(x):
    byte_img = tf.io.read_file(x)
    img = tf.io.decode_jpeg(byte_img)
    return img

# %%
ds=tf.data.Dataset.list_files('images/*.png',shuffle=False)
ds = ds.map(load_image)
ds = ds.map(lambda x: tf.image.resize(x, (32,32)))
ds = ds.map(lambda x: (x-127.5)/127.5)

# %%
len(ds)
# Out:
# 162

# %%
#lets do some duplication and concatinate to make varietyo of images
ds_copy=ds
ds = ds.concatenate(ds_copy)

# %%
len(ds)
# Out:
# 324

# %%
for elements in ds.take(1):
    plt.imshow((elements+1)/2)
    print(elements.shape)
# Out:
# (32, 32, 3)

# %%
batch_size=16
# Shuffle it up 
ds = ds.shuffle(60000)
# Batch into 128 images per sample
ds = ds.batch(batch_size)
# Reduces the likelihood of bottlenecking 
ds = ds.prefetch(8)

# %% [markdown]
# ### building the model

# %%
# Bring in the sequential api for the generator and discriminator
from tensorflow.keras.models import Sequential
# Bring in the layers for the neural network
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Reshape, LeakyReLU, Dropout, UpSampling2D,Input,BatchNormalization,MaxPooling2D,GlobalAveragePooling2D,Activation,Conv2DTranspose

# %%
def build_generator():
    model=Sequential()
    model.add(Input(shape=(100,)))
    model.add(Dense(128 * 16 * 16, activation='relu'))
    model.add(BatchNormalization(momentum=0.9))
    model.add(LeakyReLU(alpha=0.1))
    model.add(Reshape((16, 16, 128)))
    
    
    model.add(Conv2D(128, kernel_size=5, strides=1,padding='same'))
    model.add(BatchNormalization(momentum=0.9))
    model.add(LeakyReLU(alpha=0.1))
    
    
    model.add(Conv2DTranspose(128, 4, strides=2,padding='same'))
    model.add(BatchNormalization(momentum=0.9))
    model.add(LeakyReLU(alpha=0.1))
    
    model.add(Conv2D(128, kernel_size=5, strides=1,padding='same'))
    model.add(BatchNormalization(momentum=0.9))
    model.add(LeakyReLU(alpha=0.1))
    
    
    
    model.add(Conv2D(128, kernel_size=5, strides=1,padding='same'))
    model.add(BatchNormalization(momentum=0.9))
    model.add(LeakyReLU(alpha=0.1))
    
    model.add(Conv2D(3, kernel_size=5, strides=1,padding='same'))
    model.add(Activation("tanh"))
    
    return model

# %%
generator=build_generator()
generator.summary()
# Out:
# C:\Users\ACER\Desktop\traffic\ftsd\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32768)               │       3,309,568 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32768)               │         131,072 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 16, 16, 128)         │         409,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose (Conv2DTranspose)   │ (None, 32, 32, 128)         │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 32, 32, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)            │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 128)         │         409,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 32, 32, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)            │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 128)         │         409,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 32, 32, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)            │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 32, 32, 3)           │           9,603 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 32, 32, 3)           │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,943,747 (18.86 MB)
#  Trainable params: 4,877,187 (18.60 MB)
#  Non-trainable params: 66,560 (260.00 KB)

# %%
img = generator.predict(np.random.randn(4,100,1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step

# %%
# Generate new fashion
img = generator.predict(np.random.randn(4,100,1))

def rescale(img):
    img=img+1/2
    return img

img=rescale(img)
# Setup the subplot formatting 
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
# Loop four times and get images 
for idx, img in enumerate(img): 
    # Plot the image using a specific subplot 
    ax[idx].imshow(np.squeeze(img))
    # Appending the image label as the plot title 
    ax[idx].title.set_text(idx)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step

# %% [markdown]
# # Building a discriminator model

# %%
def build_discriminator():
    
    model=Sequential()
    model.add(Input(shape=(32,32,3)))
    model.add(Conv2D(128, kernel_size=3, strides=1, padding='same'))
    model.add(BatchNormalization(momentum=0.9))
    model.add(LeakyReLU(alpha=0.1))
    
    
    
    model.add(Conv2D(128, kernel_size=4, strides=2, padding='same'))
    model.add(BatchNormalization(momentum=0.9))
    model.add(LeakyReLU(alpha=0.1))
    
    
    
    model.add(Conv2D(128, kernel_size=4, strides=2, padding='same'))
    model.add(BatchNormalization(momentum=0.9))
    model.add(LeakyReLU(alpha=0.1))
    
    
    model.add(Conv2D(128, kernel_size=4, strides=2, padding='same'))
    model.add(BatchNormalization(momentum=0.9))
    model.add(LeakyReLU(alpha=0.1))
    
    
    
    
    model.add(Flatten())
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid'))
    
    
    return model

# %%
discriminator=build_discriminator()
discriminator.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 32, 32, 128)         │           3,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 32, 32, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)            │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 16, 16, 128)         │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)            │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 8, 8, 128)           │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)            │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 4, 4, 128)           │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 4, 4, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_8 (LeakyReLU)            │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │           2,049 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 794,497 (3.03 MB)
#  Trainable params: 793,473 (3.03 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %% [markdown]
# ## loss and optimizers

# %%
# Adam is going to be the optimizer for both
from tensorflow.keras.optimizers import Adam
# Binary cross entropy is going to be the loss for both 
from tensorflow.keras.losses import BinaryCrossentropy

# %%
g_opt = Adam(0.0002,0.5)
d_opt = Adam(0.0002,0.5)

# %% [markdown]
# ### losses

# %%
def discriminator_loss(real_output, fake_output):
    bce = BinaryCrossentropy(from_logits=True)
    
    
    
    # Apply noise to labels
    real_labels = tf.ones_like(real_output) 
    fake_labels = tf.zeros_like(fake_output) 
    
    # Compute losses
    real_loss = bce(real_labels, real_output)
    fake_loss = bce(fake_labels, fake_output)
    
    # Total loss
    total_loss = real_loss + fake_loss
    return total_loss

# %%
def generator_loss(fake_output):
    bce = BinaryCrossentropy(from_logits=True)
    t_loss = bce(tf.ones_like(fake_output), fake_output)
    return t_loss

# %%
g_loss=generator_loss
d_loss=discriminator_loss

# %% [markdown]
# ### model subclassing

# %%
from tensorflow.keras.models import Model
noise_dim=100

# %%
class trafficgan(Model):
    def __init__(self, generator, discriminator, *args, **kwargs):
        # Pass through args and kwargs to base class 
        super().__init__(*args, **kwargs)
        
        # Create attributes for gen and disc
        self.generator = generator 
        self.discriminator = discriminator
        
    def compile(self, g_opt, d_opt, g_loss, d_loss, *args, **kwargs): 
        # Compile with base class
        super().compile(*args, **kwargs)
        
        # Create attributes for losses and optimizers
        self.g_opt = g_opt
        self.d_opt = d_opt
        self.g_loss = g_loss
        self.d_loss = d_loss
        
    def train_step(self,images):
        noise=tf.random.normal([batch_size,noise_dim])
        with tf.GradientTape() as d_tape:
            gen_images=self.generator(noise,training=False)
            fake_output=self.discriminator(gen_images,training=True)
            real_output=self.discriminator(images,training=True)
            disc_loss=self.d_loss(real_output,fake_output)         
            
        dgrad = d_tape.gradient(disc_loss, self.discriminator.trainable_variables) 
        self.d_opt.apply_gradients(zip(dgrad, self.discriminator.trainable_variables))
        
        for _ in range(2):
            with tf.GradientTape() as g_tape:
                gen_images=self.generator(noise,training=True)
                fake_output=self.discriminator(gen_images,training=False)
                gen_loss=self.g_loss(fake_output)

            ggrad = g_tape.gradient(gen_loss, self.generator.trainable_variables)
            self.g_opt.apply_gradients(zip(ggrad, self.generator.trainable_variables))

        return {"discriminator_loss":disc_loss, "generator_loss":gen_loss}

# %%
traffic=trafficgan(generator,discriminator)

# %%
traffic.compile(g_opt,d_opt,g_loss,d_loss)

# %%
hist = traffic.fit(ds, epochs=3000)
# Out:
# Epoch 1/3000
# C:\Users\ACER\Desktop\traffic\ftsd\Lib\site-packages\keras\src\backend\tensorflow\nn.py:681: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 634ms/step - discriminator_loss: 0.1753 - generator_loss: 0.0821
# Epoch 2/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 663ms/step - discriminator_loss: 0.2032 - generator_loss: 0.1460
# Epoch 3/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 634ms/step - discriminator_loss: 0.0155 - generator_loss: 0.0127
# Epoch 4/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 637ms/step - discriminator_loss: 0.0164 - generator_loss: 0.0252
# Epoch 5/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 615ms/step - discriminator_loss: 0.0136 - generator_loss: 0.0170
# Epoch 6/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 572ms/step - discriminator_loss: 0.0295 - generator_loss: 0.0063
# Epoch 7/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 567ms/step - discriminator_loss: 0.1006 - generator_loss: 0.5394
# Epoch 8/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 565ms/step - discriminator_loss: 0.0403 - generator_loss: 0.0672
# Epoch 9/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 565ms/step - discriminator_loss: 0.0035 - generator_loss: 0.0107
# Epoch 10/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 567ms/step - discriminator_loss: 0.0028 - generator_loss: 0.0083
# Epoch 11/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 565ms/step - discriminator_loss: 0.0018 - generator_loss: 0.0061
# Epoch 12/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 569ms/step - discriminator_loss: 0.0012 - generator_loss: 0.0051
# Epoch 13/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 567ms/step - discriminator_loss: 0.0013 - generator_loss: 0.0037
# Epoch 14/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 565ms/step - discriminator_loss: 8.6122e-04 - generator_loss: 0.0030
# Epoch 15/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 566ms/step - discriminator_loss: 7.0841e-04 - generator_loss: 0.0025
# Epoch 16/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 576ms/step - discriminator_loss: 4.5418e-04 - generator_loss: 0.0022
# Epoch 17/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 567ms/step - discriminator_loss: 5.2992e-04 - generator_loss: 0.0018
# Epoch 18/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 567ms/step - discriminator_loss: 3.9452e-04 - generator_loss: 0.0016
# Epoch 19/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 566ms/step - discriminator_loss: 3.4931e-04 - generator_loss: 0.0015
# Epoch 20/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 567ms/step - discriminator_loss: 3.5175e-04 - generator_loss: 0.0014
# Epoch 21/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 566ms/step - discriminator_loss: 2.4101e-04 - generator_loss: 0.0011
# Epoch 22/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 571ms/step - discriminator_loss: 2.2458e-04 - generator_loss: 0.0011
# Epoch 23/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 568ms/step - discriminator_loss: 2.1424e-04 - generator_loss: 0.0010
# Epoch 24/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 567ms/step - discriminator_loss: 1.8363e-04 - generator_loss: 9.7745e-04
# Epoch 25/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 566ms/step - discriminator_loss: 2.2753e-04 - generator_loss: 8.9128e-04
# Epoch 26/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 572ms/step - discriminator_loss:
3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 574ms/step - discriminator_loss: 4.7830e-07 - generator_loss: 2.9936e-07
# Epoch 378/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 580ms/step - discriminator_loss: 4.7785e-07 - generator_loss: 2.9466e-07
# Epoch 379/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 576ms/step - discriminator_loss: 1.6301e-06 - generator_loss: 2.8433e-07
# Epoch 380/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 577ms/step - discriminator_loss: 4.7164e-07 - generator_loss: 1.8378e-07
# Epoch 381/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 579ms/step - discriminator_loss: 8.7009e-07 - generator_loss: 1.8108e-07
# Epoch 382/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 577ms/step - discriminator_loss: 5.4998e-07 - generator_loss: 1.8698e-07
# Epoch 383/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 575ms/step - discriminator_loss: 4.4945e-07 - generator_loss: 1.8713e-07
# Epoch 384/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 573ms/step - discriminator_loss: 4.8038e-07 - generator_loss: 1.9397e-07
# Epoch 385/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 578ms/step - discriminator_loss: 4.6919e-07 - generator_loss: 2.0110e-07
# Epoch 386/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 577ms/step - discriminator_loss: 4.1427e-07 - generator_loss: 2.1060e-07
# Epoch 387/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 572ms/step - discriminator_loss: 4.1981e-07 - generator_loss: 2.1628e-07
# Epoch 388/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 580ms/step - discriminator_loss: 4.1031e-07 - generator_loss: 2.1733e-07
# Epoch 389/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 577ms/step - discriminator_loss: 5.4032e-07 - generator_loss: 2.0741e-07
# Epoch 390/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 575ms/step - discriminator_loss: 4.8090e-07 - generator_loss: 2.1386e-07
# Epoch 391/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 581ms/step - discriminator_loss: 4.7315e-07 - generator_loss: 2.1430e-07
# Epoch 392/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 576ms/step - discriminator_loss: 3.7097e-07 - generator_loss: 2.0412e-07
# Epoch 393/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 578ms/step - discriminator_loss: 5.7464e-07 - generator_loss: 2.1327e-07
# Epoch 394/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 579ms/step - discriminator_loss: 4.5851e-07 - generator_loss: 1.9900e-07
# Epoch 395/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 582ms/step - discriminator_loss: 3.6438e-07 - generator_loss: 1.8666e-07
# Epoch 396/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 577ms/step - discriminator_loss: 4.2811e-07 - generator_loss: 1.9918e-07
# Epoch 397/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 577ms/step - discriminator_loss: 6.1207e-07 - generator_loss: 2.1282e-07
# Epoch 398/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 579ms/step - discriminator_loss: 3.9924e-07 - generator_loss: 2.1627e-07
# Epoch 399/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 579ms/step - discriminator_loss: 4.2006e-07 - generator_loss: 2.0581e-07
# Epoch 400/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 578ms/step - discriminator_loss: 3.0052e-06 - generator_loss: 1.9742e-07
# Epoch 401/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 575ms/step - discriminator_loss: 4.8103e-07 - generator_loss: 1.0771e-07
# Epoch 402/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 577ms/step - discriminator_loss: 7.8275e-07 - generator_loss: 1.2497e-07
# Epoch 403/3000
# ...
# Epoch 2868/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 638ms/step - discriminator_loss: 1.8200e-10 - generator_loss: 1.3512e-09
# Epoch 2869/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 629ms/step - discriminator_loss: 3.3532e-10 - generator_loss: 1.3550e-09
# Epoch 2870/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 638ms/step - discriminator_loss: 1.7489e-10 - generator_loss: 1.2646e-09
# Epoch 2871/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 637ms/step - discriminator_loss: 2.1400e-10 - generator_loss: 1.2753e-09
# Epoch 2872/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 635ms/step - discriminator_loss: 1.8412e-10 - generator_loss: 1.3199e-09
# Epoch 2873/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 634ms/step - discriminator_loss: 1.7007e-10 - generator_loss: 1.3099e-09
# Epoch 2874/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 634ms/step - discriminator_loss: 1.7488e-10 - generator_loss: 1.4633e-09
# Epoch 2875/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 636ms/step - discriminator_loss: 2.6333e-10 - generator_loss: 1.3720e-09
# Epoch 2876/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s
3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 638ms/step - discriminator_loss: 2.6733e-10 - generator_loss: 1.6917e-09
# Epoch 2977/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 637ms/step - discriminator_loss: 2.6289e-10 - generator_loss: 1.7956e-09
# Epoch 2978/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 631ms/step - discriminator_loss: 1.8089e-10 - generator_loss: 1.4943e-09
# Epoch 2979/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 636ms/step - discriminator_loss: 2.1654e-10 - generator_loss: 1.6026e-09
# Epoch 2980/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 637ms/step - discriminator_loss: 1.6220e-10 - generator_loss: 1.5978e-09
# Epoch 2981/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 638ms/step - discriminator_loss: 1.8189e-10 - generator_loss: 1.7066e-09
# Epoch 2982/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 641ms/step - discriminator_loss: 1.6891e-10 - generator_loss: 1.5483e-09
# Epoch 2983/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 641ms/step - discriminator_loss: 2.0857e-10 - generator_loss: 1.7117e-09
# Epoch 2984/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 627ms/step - discriminator_loss: 3.5194e-10 - generator_loss: 1.6705e-09
# Epoch 2985/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 637ms/step - discriminator_loss: 3.6065e-10 - generator_loss: 1.8582e-09
# Epoch 2986/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 635ms/step - discriminator_loss: 2.1705e-10 - generator_loss: 1.6842e-09
# Epoch 2987/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 636ms/step - discriminator_loss: 2.2765e-10 - generator_loss: 1.6052e-09
# Epoch 2988/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 635ms/step - discriminator_loss: 2.3022e-10 - generator_loss: 1.6083e-09
# Epoch 2989/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 636ms/step - discriminator_loss: 1.6463e-10 - generator_loss: 1.6489e-09
# Epoch 2990/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 638ms/step - discriminator_loss: 1.9862e-10 - generator_loss: 1.8320e-09
# Epoch 2991/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 637ms/step - discriminator_loss: 2.3557e-10 - generator_loss: 1.4931e-09
# Epoch 2992/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 635ms/step - discriminator_loss: 1.6891e-10 - generator_loss: 1.6730e-09
# Epoch 2993/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 638ms/step - discriminator_loss: 1.7049e-10 - generator_loss: 1.5283e-09
# Epoch 2994/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 634ms/step - discriminator_loss: 2.1021e-10 - generator_loss: 1.8032e-09
# Epoch 2995/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 657ms/step - discriminator_loss: 1.9399e-10 - generator_loss: 1.5288e-09
# Epoch 2996/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 630ms/step - discriminator_loss: 1.8194e-10 - generator_loss: 1.6963e-09
# Epoch 2997/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 636ms/step - discriminator_loss: 1.9871e-10 - generator_loss: 1.8252e-09
# Epoch 2998/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 640ms/step - discriminator_loss: 1.8113e-10 - generator_loss: 1.7944e-09
# Epoch 2999/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 637ms/step - discriminator_loss: 2.3181e-10 - generator_loss: 1.7339e-09
# Epoch 3000/3000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 637ms/step - discriminator_loss: 2.4042e-10 - generator_loss: 1.5729e-09

# %%
imgs = generator.predict(tf.random.normal((16, 100, 1)))
imgs.shape
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# (16, 32, 32, 3)

# %%
imgs = generator.predict(tf.random.normal((16, 100, 1)))

def rescale_images(images):
    return (images + 1) / 2  # Rescale from [-1, 1] to [0, 1]


img_rescaled = rescale_images(imgs)

fig, ax = plt.subplots(ncols=4, nrows=4, figsize=(10,10))
for r in range(4):
    for c in range(4):
        ax[r][c].imshow(img_rescaled[(r+1)*(c+1)-1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step

# %%
# Save the entire model to a HDF5 file
generator.save('generatormodelone.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Save the entire model to a HDF5 file
discriminator.save('discriminatormodelone.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
plt.suptitle('Loss')
plt.plot(hist.history['discriminator_loss'], label='discriminator_loss')
plt.plot(hist.history['generator_loss'], label='generator_loss')
plt.legend()
plt.show()
